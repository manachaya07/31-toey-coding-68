# %% [markdown]
# <a href="https://colab.research.google.com/github/manachaya07/31-toey-coding-68/blob/main/31_manachaya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("ชื่ออะไรคะ")
print("สวัสดีค่ะคุณ", name, "ยินดีต้อนรับสู่โปรแกรมล็อกโทรศัพท์")
datetime_now = float(input("เวลานอน (ชั่วโมง): "))
end_time = float(input("เวลาตื่น (ชั่วโมง): "))

sleep_time = (24 - datetime_now) + end_time

if sleep_time < 8:
    print("นอนไม่พอ ควรนอนอย่างน้อย 8 ชั่วโมง")

while time.localtime().tm_hour != int(datetime_now):
    print("กำลังรอเวลานอน")
    time.sleep(60)

print("ถึงเวลานอน หากไม่นอนล็อกโทรศัพท์ 30 นาที")
time.sleep(30 * 60)
print("ปลดล็อกแล้ว")
