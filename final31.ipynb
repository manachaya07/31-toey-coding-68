# %% [markdown]
# <a href="https://colab.research.google.com/github/manachaya07/31-toey-coding-68/blob/main/final31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
birthr= int(input("กรุณาใส่ปีเกิด (ค.ศ.): "))
current=int(input("กรุณาใส่ปีปัจจุบัน (ค.ศ.): "))
age= current - birthr

print("คุณอายุ" ,age, "ปีครับ")
#มนัชญา 31
# Out:
# กรุณาใส่ปีเกิด (ค.ศ.): 2001
# กรุณาใส่ปีปัจจุบัน (ค.ศ.): 2025
# คุณอายุ 24 ปีครับ
